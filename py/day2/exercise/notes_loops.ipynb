# %% [markdown]
# Here’s a practical, step-by-step way to improve logical thinking for Python programming, especially useful for students 👇
#
# 1️⃣ Think in Plain English First (No Code Allowed)
#
# Before touching Python, force yourself to answer these questions:
#
# What is the input?
#
# What decisions need to be made?
#
# What is the output?
#
# What happens if the input is wrong?
#
# Example (BMI Program)
#
# Plain English logic:
#
# Ask user for weight (kg)
#
# Ask user for height (m)
#
# Calculate BMI = weight / (height × height)
#
# If BMI < 18.5 → Underweight
#
# Else if BMI < 25 → Normal
#
# Else if BMI < 30 → Overweight
#
# Else → Obese
#
# Only after this do you write Python.

# %% [markdown]
# 2️⃣ Use “If / Then / Else” Sentences
#
# Train your brain to speak like a computer:
#
# ❌ “Check BMI category”
# ✅ “If BMI is less than 18.5, then print underweight”
#
# Write it like this in a notebook:

# %%
IF condition is true
    THEN do this
ELSE
    do something else

# %% [markdown]
# Python is just a translation of this thinking.
#
# 3️⃣ Draw Simple Flow Diagrams
#
# You don’t need fancy tools. Boxes and arrows work.

# %% [markdown]
# Start
#   ↓
# Get user input
#   ↓
# Calculate result
#   ↓
# Is result < X?
#  ├─ Yes → Output A
#  └─ No → Is result < Y?
#           ├─ Yes → Output B
#           └─ No → Output C

# %% [markdown]
# If you can’t draw it, you’re not ready to code it.

# %% [markdown]
# 4️⃣ Break Problems Into Tiny Steps
#
# Beginners try to solve everything at once.
#
# Instead:
#
# Solve one decision
#
# Test it
#
# Then add the next
#
# Example:
#
# Get input ✔
#
# Print input ✔
#
# Calculate value ✔
#
# Add first if ✔
#
# Add second elif ✔
#
# Small wins = strong logic.

# %% [markdown]
# 5️⃣ Predict Output Before Running Code
#
# Before pressing Run, ask:
#
# “What should this print?”
#
# Then check:
#
# If it matches → logic is correct
#
# If not → your thinking is wrong (not Python)
#
# This builds mental simulation, a key programmer skill.

# %% [markdown]
# 6️⃣ Read Code Like a Story
#
# When reading Python, say it out loud:

# %%
if score >= 50:
    print("Pass")
else:
    print("Fail")

# %% [markdown]
# Becomes:
#
# “If score is greater than or equal to 50, then print Pass, otherwise print Fail.”
#
# If you can’t explain it, you don’t understand it.

# %% [markdown]
# 7️⃣ Practice Logic-First Exercises
#
# Do problems that focus on decision making, not syntax:
#
# Number guessing game
#
# Grade calculator
#
# ATM withdrawal logic
#
# Traffic light simulator
#
# Login system (username + password)
#
# Always:
#
# Write logic in English
#
# Draw flow
#
# Then code

# %% [markdown]
# 8️⃣ Debug by Asking WHY (Not WHAT)
#
# ❌ “Why is this not working?”
# ✅ “Which condition is failing?”
#
# Check:
#
# Is the if condition correct?
#
# Is the order of elif wrong?
#
# Is something always true?
#
# Most logic bugs = wrong condition order.

# %% [markdown]
# 9️⃣ Think Like Python (No Emotions 😄)
#
# Python doesn’t “guess” or “understand intent”.
#
# It only knows:
#
# True or False
#
# Top to bottom
#
# First matching condition wins
#
# Train yourself to think mechanically, not emotionally.

# %% [markdown]
# 10️⃣ Golden Rule for Beginners 🧠
#
# If you can explain your program in English, Python will be easy.
# If you can’t, Python will feel impossible.

# %% [markdown]
# 📅 PART 1: Daily Logic Drills (10–15 min/day)
# 🔹 Drill Rule (VERY IMPORTANT)
#
# 🚫 No Python at first
# ✅ English → Flow → Prediction → Code
#
# 🟢 Day 1 – Single Decision Logic
#
# Problem: Pass or Fail
#
# English Logic
#
# Ask user for score
#
# If score ≥ 50 → Pass
#
# Else → Fail
#
# Think Before Coding
#
# What if score = 49?
#
# What if score = 50?
#
# What if score = 100?

# %% [markdown]
# 🟢 Day 2 – Multiple Conditions
#
# Problem: Grade System
#
# English Logic
#
# If score ≥ 80 → A
#
# Else if score ≥ 60 → B
#
# Else if score ≥ 40 → C
#
# Else → F
#
# 🧠 Logic trap: Order matters
# (If you put >=40 first, everything breaks)

# %% [markdown]
# 🟢 Day 3 – Boolean Logic
#
# Problem: Login System
#
# English Logic
#
# Ask for username
#
# Ask for password
#
# If username is correct AND password is correct → Login success
#
# Else → Login failed

# %% [markdown]
# 🟢 Day 4 – Range Checking
#
# Problem: Age Category
#
# Age < 13 → Child
#
# Age 13–19 → Teen
#
# Age 20–59 → Adult
#
# Age ≥ 60 → Senior

# %% [markdown]
# 🟢 Day 5 – Nested Logic
#
# Problem: ATM Withdrawal
#
# If balance ≥ withdrawal:
#
# If withdrawal ≤ daily limit → Success
#
# Else → Limit exceeded
#
# Else → Insufficient funds

# %% [markdown]
# 📄 PART 2: Logic-First Worksheet (Use This Template)
#
# Copy this every time you solve a problem:
#
# 1. INPUT:
#    - What data do I need?
#
# 2. PROCESS:
#    - What calculations?
#    - What decisions?
#
# 3. CONDITIONS (If / Else):
#    - If __________ then __________
#    - Else if __________ then __________
#    - Else __________
#
# 4. OUTPUT:
#    - What should be displayed?
#
# 5. EDGE CASES:
#    - Smallest value?
#    - Largest value?
#    - Invalid input?
#
# If you fill this correctly → Python is easy.

# %% [markdown]
# 🔄 PART 3: English → Python Translation Example
# English
#
# If temperature is greater than 30, print “Hot”, otherwise print “Normal”.

# %%
if temperature > 30:
    print("Hot")
else:
    print("Normal")

# Never write Python before the English sentence.

# %% [markdown]
# 🐛 PART 4: Common Beginner Logic Mistakes (VERY IMPORTANT)
# ❌ Mistake 1: Wrong Condition Order

# %%
if score >= 40:
    print("C")
elif score >= 80:
    print("A")

# %% [markdown]
# ✅ Correct:

# %%
if score >= 80:
    print("A")
elif score >= 40:
    print("C")

# %% [markdown]
# ❌ Mistake 2: Overlapping Conditions

# %%
if age > 18:
    ...
elif age > 13:
    ...
# 🧠 Ask: Can both be true?

# %% [markdown]
# ❌ Mistake 3: Assuming Python “Understands”
#
# Python does exactly what you say — not what you mean.

# %% [markdown]
# 🧪 PART 5: Predict-Before-Run Exercise
#
# Before running this code, answer first:

# %%
x = 10

if x > 5:
    print("A")
if x > 8:
    print("B")
else:
    print("C")

# %% [markdown]
# 🧠 Expected Output: A B
#
# Why?
# Because the else belongs only to the second if.

# %% [markdown]
# 🏆 PART 6: Mental Model to Remember Forever
#
# Python reads:
#
# Top to bottom
#
# One line at a time
#
# First matching condition wins
#
# True or False only
#
# No guessing. No emotions 😄

# %% [markdown]
# 🎯 PART 7: Challenge (Do This NOW)
#
# Problem: Traffic Light
#
# Write ONLY English logic (no Python yet):
#
# Red → Stop
#
# Yellow → Slow down
#
# Green → Go
#
# Anything else → Invalid signal
#
# Reply with:
# 1️⃣ English logic
# 2️⃣ Then I’ll review it
# 3️⃣ Then we convert it to Python together
#
# You’re learning this the right way.
# This is how real programmers think 💪

# %% [markdown]
# ✅ Step 1: Refine Your English Logic (Clear & Precise)
#
# Your version:
#
# if light is red, stop. if light is yellow, slow down, if light is green, go. other than this 3 colors, invalid signal.
#
# Programmer-ready English logic:
#
# Ask user for traffic light color
#
# If color is "red", then stop
#
# Else if color is "yellow", then slow down
#
# Else if color is "green", then go
#
# Else, invalid signal
#
# 🧠 Improvement made:
#
# Added Else if instead of multiple if
#
# Ensured only one action happens
#
# Covered all other inputs

# %% [markdown]
# ⚠️ Step 2: Logic Check (Think Like Python)
#
# Ask yourself:
#
# What if input = "Red" (capital R)?
#
# What if input = "GREEN"?
#
# What if input = "blue"?
#
# 👉 Python is case-sensitive, so logic must handle that.
#
# Solution (still English):
#
# Convert input to lowercase before checking

# %%
light = input("Enter traffic light color: ").lower()

if light == "red":
    print("Stop")
elif light == "yellow":
    print("Slow down")
elif light == "green":
    print("Go")
else:
    print("Invalid signal")
